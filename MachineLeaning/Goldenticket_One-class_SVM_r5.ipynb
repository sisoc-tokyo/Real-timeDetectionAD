# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.decomposition import PCA
from sklearn.externals import joblib

# %%
df = pd.read_csv('eventlog_psexe.csv')
print(df)
# Out:
#                    date  eventID          account             ip  \
# 0       2018/04/03 0:00     5140              dc$           fe80
# 1       2018/04/03 0:00     5140              dc$           fe80
# 2       2018/04/03 0:00     5140              dc$           fe80
# 3       2018/04/03 0:00     5140              dc$           fe80
# 4       2018/04/03 0:02     5140              dc$           fe80
# 5       2018/04/03 0:02     5140              dc$           fe80
# 6       2018/04/03 0:03     5140          fsadmin  192.168.2.102
# 7       2018/04/03 0:03     5140          fsadmin  192.168.2.102
# 8       2018/04/03 0:03     5140          fsadmin  192.168.2.102
# 9       2018/04/03 0:03     5140          fsadmin  192.168.2.102
# 10      2018/04/03 0:03     5140              dc$           fe80
# 11      2018/04/03 0:03     5140              dc$           fe80
# 12      2018/04/03 0:03     5140              dc$           fe80
# 13      2018/04/03 0:03     5140              dc$           fe80
# 14      2018/04/03 0:05     5140    local service  192.168.2.102
# 15      2018/04/03 0:05     5140          filesv$  192.168.2.102
# 16      2018/04/03 0:05     5140          filesv$  192.168.2.102
# 17      2018/04/03 0:08     5140              dc$           fe80
# 18      2018/04/03 0:08     5140              dc$           fe80
# 19      2018/04/03 0:09     5140    local service  192.168.2.102
# 20      2018/04/03 0:09     5140          filesv$  192.168.2.102
# 21      2018/04/03 0:09     5140          filesv$  192.168.2.102
# 22      2018/04/03 0:10     5140              dc$           fe80
# 23      2018/04/03 0:10     5140              dc$           fe80
# 24      2018/04/03 0:13     5140              dc$           fe80
# 25      2018/04/03 0:13     5140              dc$           fe80
# 26      2018/04/03 0:17     5140              dc$           fe80
# 27      2018/04/03 0:17     5140              dc$           fe80
# 28      2018/04/03 0:17     5140    local service           fe80
# 29      2018/04/03 0:18     5140              dc$           fe80
# ...                 ...      ...              ...            ...
# 41085  2018/04/23 16:26     5140              dc$           fe80
# 41086  2018/04/23 16:26     4674    local service            NaN
# 41087  2018/04/23 16:26     4674    local service            NaN
# 41088  2018/04/23 16:26     4674    local service            NaN
# 41089  2018/04/23 16:27     5140     yoshinoripc$   192.168.2.26
# 41090  2018/04/23 16:27     5140     yoshinoripc$   192.168.2.26
# 41091  2018/04/23 16:28     5140  anonymous logon     10.1.2.101
# 41092  2018/04/23 16:28     5140  anonymous logon     10.1.2.101
# 41093  2018/04/23 16:28     5140  anonymous logon     10.1.2.101
# 41094  2018/04/23 16:28     5140  anonymous logon     10.1.2.101
# 41095  2018/04/23 16:28     5140      student2-a$     10.1.2.101
# 41096  2018/04/23 16:28     5140      student2-a$     10.1.2.101
# 41097  2018/04/20 10:53     4674            admin   192.168.2.16
# 41098  2018/04/20 10:57     4674            admin   192.168.2.16
# 41099  2018/04/20 11:01     4674            admin   192.168.2.16
# 41100  2018/04/21 11:23     4674            admin   192.168.2.16
# 41101  2018/04/21 11:33     4674            admin            NaN
# 41102  2018/04/21 11:51     4674            admin   192.168.2.16
# 41103  2018/04/22 11:17     4674            admin   192.168.2.16
# 41104  2018/04/22 11:30     4674            admin   192.168.2.16
# 41105  2018/04/22 11:40     4674            admin            NaN
# 41106  2018/04/20 14:51     4674            admin   192.168.2.16
# 41107  2018/04/20 14:52     4674            admin   192.168.2.16
# 41108  2018/04/20 15:03     4674            admin   192.168.2.16
# 41109  2018/04/19 14:39     4688            admin            NaN
# 41110  2018/04/19 14:39     4688            admin            NaN
# 41111  2018/04/19 14:39     4688          user101   192.168.2.15
# 41112  2018/04/19 14:39     4688          user101   192.168.2.15
# 41113  2018/04/19 14:39     4688          user101   192.168.2.15
# 41114  2018/04/19 14:39     4688          user101   192.168.2.15
#
#                          service                        process objectname  \
# 0                        FILESV$                            NaN        NaN
# 1                        FILESV$                            NaN        NaN
# 2                        FILESV$                            NaN        NaN
# 3                        FILESV$                            NaN        NaN
# 4                        FILESV$                            NaN        NaN
# 5                        FILESV$                            NaN        NaN
# 6                        FILESV$                            NaN        NaN
# 7                        FILESV$                            NaN        NaN
# 8                        FILESV$                            NaN        NaN
# 9                        FILESV$                            NaN        NaN
# 10                       FILESV$                            NaN        NaN
# 11                       FILESV$                            NaN        NaN
# 12                       FILESV$                            NaN        NaN
# 13                       FILESV$                            NaN        NaN
# 14                       FILESV$                            NaN        NaN
# 15                       FILESV$                            NaN        NaN
# 16                       FILESV$                            NaN        NaN
# 17                           DC$                            NaN        NaN
# 18                           DC$                            NaN        NaN
# 19                           DC$                            NaN        NaN
# 20                           DC$                            NaN        NaN
# 21                           DC$                            NaN        NaN
# 22                           DC$                            NaN        NaN
# 23                           DC$                            NaN        NaN
# 24                           DC$                            NaN        NaN
# 25                           DC$                            NaN        NaN
# 26                           DC$                            NaN        NaN
# 27                           DC$                            NaN        NaN
# 28                           DC$                            NaN        NaN
# 29                           DC$                            NaN        NaN
# ...                          ...                            ...        ...
# 41085                        NaN                            NaN        NaN
# 41086                        NaN  c:\windows\system32\lsass.exe          -
# 41087                        NaN  c:\windows\system32\lsass.exe          -
# 41088                        NaN  c:\windows\system32\lsass.exe          -
# 41089                        NaN                            NaN        NaN
# 41090                        NaN                            NaN        NaN
# 41091                        NaN                            NaN        NaN
# 41092                        NaN                            NaN        NaN
# 41093                        NaN                            NaN        NaN
# 41094                        NaN                            NaN        NaN
# 41095                        NaN                            NaN        NaN
# 41096                        NaN                            NaN        NaN
# 41097                        DC$                       psexesvc   psexesvc
# 41098                     krbtgt                       psexesvc   psexesvc
# 41099                STUDENT4-B$                       psexesvc   psexesvc
# 41100  LsaRegisterLogonProcess()                       psexesvc   psexesvc
# 41101                    FILESV$                       psexesvc   psexesvc
# 41102                          -                       psexesvc   psexesvc
# 41103                     krbtgt                       psexesvc   psexesvc
# 41104  LsaRegisterLogonProcess()                       psexesvc   psexesvc
# 41105                        DC$                       psexesvc   psexesvc
# 41106                          -                       psexesvc   psexesvc
# 41107                        DC$                       psexesvc   psexesvc
# 41108                        DC$                       psexesvc   psexesvc
# 41109                        DC$    c:\windows\system32\net.exe        NaN
# 41110                        DC$   c:\windows\system32\net1.exe        NaN
# 41111                        DC$    c:\windows\system32\net.exe        NaN
# 41112                        DC$   c:\windows\system32\net1.exe        NaN
# 41113                        DC$    c:\windows\system32\net.exe        NaN
# 41114                        DC$   c:\windows\system32\net1.exe        NaN
#
#        sharedname   target
# 0        \\*\ipc$    train
# 1             NaN    train
# 2      \\*\sysvol    train
# 3             NaN    train
# 4        \\*\ipc$    train
# 5             NaN    train
# 6        \\*\ipc$    train
# 7             NaN    train
# 8      \\*\sysvol    train
# 9             NaN    train
# 10       \\*\ipc$    train
# 11            NaN    train
# 12     \\*\sysvol    train
# 13            NaN    train
# 14     \\*\sysvol    train
# 15     \\*\sysvol    train
# 16            NaN    train
# 17     \\*\sysvol    train
# 18            NaN    train
# 19       \\*\ipc$    train
# 20       \\*\ipc$    train
# 21            NaN    train
# 22     \\*\sysvol    train
# 23            NaN    train
# 24     \\*\sysvol    train
# 25            NaN    train
# 26       \\*\ipc$    train
# 27            NaN    train
# 28       \\*\ipc$    train
# 29       \\*\ipc$    train
# ...           ...      ...
# 41085         NaN    train
# 41086         NaN    train
# 41087         NaN    train
# 41088         NaN    train
# 41089    \\*\ipc$    train
# 41090         NaN    train
# 41091    \\*\ipc$    train
# 41092         NaN    train
# 41093    \\*\ipc$    train
# 41094         NaN    train
# 41095    \\*\ipc$    train
# 41096         NaN    train
# 41097         NaN    train
# 41098         NaN    train
# 41099         NaN    train
# 41100         NaN    train
# 41101         NaN    train
# 41102         NaN    train
# 41103         NaN    train
# 41104         NaN    train
# 41105         NaN    train
# 41106         NaN    train
# 41107         NaN    train
# 41108         NaN    train
# 41109         NaN  outlier
# 41110         NaN  outlier
# 41111         NaN  outlier
# 41112         NaN  outlier
# 41113         NaN  outlier
# 41114         NaN  outlier
#
# [41115 rows x 9 columns]

# %% [markdown]
# One-class SVM

# %%
def learning(eventid, df, nu, gamma):
    
    df = df[df.eventID == eventid]
    data_dummies = pd.get_dummies(df.iloc[:,1:])
    data_dummies = pd.concat([df.iloc[:,0], data_dummies], axis=1)
    data_dummies.to_csv('data_dummies_' + str(eventid) + '.csv')

    if 'train' not in df.target.values:
        print('No train value in the target column')
        print('')
        return

    if 'test' not in df.target.values:
        print('No test value in the target column')
        print('')
        return
    
    if 'outlier' not in df.target.values:
        print('No outlier value in the target column')
        print('')
        return

    data_normal = data_dummies[data_dummies.target_train == 1]
    data_test = data_dummies[data_dummies.target_test == 1]
    data_outliers = data_dummies[data_dummies.target_outlier == 1]
    X_train = data_normal.ix[:, 1:-3].values
    X_test = data_test.ix[:, 1:-3].values
    X_outliers = data_outliers.ix[:, 1:-3].values
    
    X_all = data_dummies.ix[:, 1:-3].values
    X_index = data_dummies.ix[:, -3:].values
    
    clf = svm.OneClassSVM(nu=nu, kernel="rbf", gamma=gamma)
    clf.fit(X_train)
    
    #n_correct_test is True Negative
    #n_error_test is False Positive
    #n_correct_outliers is True Positive
    #n_error_outliers is False Negative

    X_pred_train = clf.predict(X_train)
    X_pred_test = clf.predict(X_test)
    X_pred_outliers = clf.predict(X_outliers)
    n_correct_train = X_pred_train[X_pred_train == 1].size
    n_error_train = X_pred_train[X_pred_train == -1].size
    n_correct_test = X_pred_test[X_pred_test == 1].size
    n_error_test = X_pred_test[X_pred_test == -1].size
    n_correct_outliers = X_pred_outliers[X_pred_outliers == -1].size
    n_error_outliers = X_pred_outliers[X_pred_outliers == 1].size
    recall = n_correct_outliers / (n_correct_outliers + n_error_outliers)
    precision = n_correct_outliers / (n_correct_outliers + n_error_test)
    specificity = n_correct_test / (n_correct_test + n_error_test)
    accuracy = (n_correct_test + n_correct_outliers) / (n_correct_test + n_error_test + n_correct_outliers + n_error_outliers)
    f_value = (2 * n_correct_outliers) / (2 * n_correct_outliers + n_error_test + n_error_outliers)
    
    print('svm.OneClassSVM(nu=' + str(nu) + ', kernel="rbf", gamma=' + str(gamma) + ')')
    print('Training Correct: ' + str(n_correct_train))
    print('Training Error: ' + str(n_error_train))
    print('True Negative: ' + str(n_correct_test))
    print('False Positive: ' + str(n_error_test))
    print('True Positive: ' + str(n_correct_outliers))
    print('False Negative: ' + str(n_error_outliers))
    print('Recall: ' + str(recall))
    print('Precision: ' + str(precision))
    print('Specificity: ' + str(specificity))
    print('Accuracy: ' + str(accuracy))
    print('F_Value: ' + str(f_value))
    print('N: ' + str(n_correct_train+n_error_train+n_correct_test+n_error_test+n_correct_outliers+n_error_outliers))
    print('')
    
    X_train_result = np.concatenate((df[df['target'] == 'train'], X_pred_train[np.newaxis, :].T), axis=1)
    X_test_result = np.concatenate((df[df['target'] == 'test'], X_pred_test[np.newaxis, :].T), axis=1)
    X_outliers_result = np.concatenate((df[df['target'] == 'outlier'], X_pred_outliers[np.newaxis, :].T), axis=1)

    with open('X_train_result' + str(eventid) + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerows(X_train_result)
    
    with open('X_test_result' + str(eventid) + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerows(X_test_result)

    with open('X_outliers_result' + str(eventid) + '.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerows(X_outliers_result)
        
    #print('PCA')
    #pca = PCA(n_components=2)
    #X_pca = pca.fit_transform(X_all)

    #plt.figure()
    #plt.scatter(X_pca[:,0], X_pca[:,1], c=X_index)
    #plt.title('Red:' + data_dummies.columns[-3] + '  Green:' + data_dummies.columns[-2] + '  Blue:' + data_dummies.columns[-1])
    #plt.show()

    joblib.dump(clf, 'ocsvm_gt_' + str(eventid) + '.pkl')

# %%
nu_list = [0.1, 0.01, 0.001]
gamma_list = [0.1, 0.01, 0.001]

for nu in nu_list:
    for gamma in gamma_list:
        #learning(4672, df, nu, gamma)
        #learning(4673, df, nu, gamma)
        learning(4674, df, nu, gamma)
        #learning(4688, df, nu, gamma)
        #learning(4768, df, nu, gamma)
        #learning(4769, df, nu, gamma)
        #learning(5140, df, nu, gamma)
# Out:
# svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)
# Training Correct: 815
# Training Error: 123
# True Negative: 47
# False Positive: 5
# True Positive: 15
# False Negative: 14
# Recall: 0.5172413793103449
# Precision: 0.75
# Specificity: 0.9038461538461539
# Accuracy: 0.7654320987654321
# F_Value: 0.6122448979591837
# N: 1019
#
# svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.01)
# Training Correct: 829
# Training Error: 109
# True Negative: 47
# False Positive: 5
# True Positive: 10
# False Negative: 19
# Recall: 0.3448275862068966
# Precision: 0.6666666666666666
# Specificity: 0.9038461538461539
# Accuracy: 0.7037037037037037
# F_Value: 0.45454545454545453
# N: 1019
#
# svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.001)
# Training Correct: 842
# Training Error: 96
# True Negative: 47
# False Positive: 5
# True Positive: 8
# False Negative: 21
# Recall: 0.27586206896551724
# Precision: 0.6153846153846154
# Specificity: 0.9038461538461539
# Accuracy: 0.6790123456790124
# F_Value: 0.38095238095238093
# N: 1019
#
# svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.1)
# Training Correct: 873
# Training Error: 65
# True Negative: 50
# False Positive: 2
# True Positive: 12
# False Negative: 17
# Recall: 0.41379310344827586
# Precision: 0.8571428571428571
# Specificity: 0.9615384615384616
# Accuracy: 0.7654320987654321
# F_Value: 0.5581395348837209
# N: 1019
#
# svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.01)
# Training Correct: 884
# Training Error: 54
# True Negative: 50
# False Positive: 2
# True Positive: 5
# False Negative: 24
# Recall: 0.1724137931034483
# Precision: 0.7142857142857143
# Specificity: 0.9615384615384616
# Accuracy: 0.6790123456790124
# F_Value: 0.2777777777777778
# N: 1019
#
# svm.OneClassSVM(nu=0.01, kernel="rbf", gamma=0.001)
# Training Correct: 850
# Training Error: 88
# True Negative: 52
# False Positive: 0
# True Positive: 8
# False Negative: 21
# Recall: 0.27586206896551724
# Precision: 1.0
# Specificity: 1.0
# Accuracy: 0.7407407407407407
# F_Value: 0.43243243243243246
# N: 1019
#
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.1)
# Training Correct: 836
# Training Error: 102
# True Negative: 50
# False Positive: 2
# True Positive: 11
# False Negative: 18
# Recall: 0.3793103448275862
# Precision: 0.8461538461538461
# Specificity: 0.9615384615384616
# Accuracy: 0.7530864197530864
# F_Value: 0.5238095238095238
# N: 1019
#
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.01)
# Training Correct: 852
# Training Error: 86
# True Negative: 52
# False Positive: 0
# True Positive: 10
# False Negative: 19
# Recall: 0.3448275862068966
# Precision: 1.0
# Specificity: 1.0
# Accuracy: 0.7654320987654321
# F_Value: 0.5128205128205128
# N: 1019
#
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.001)
# Training Correct: 608
# Training Error: 330
# True Negative: 47
# False Positive: 5
# True Positive: 23
# False Negative: 6
# Recall: 0.7931034482758621
# Precision: 0.8214285714285714
# Specificity: 0.9038461538461539
# Accuracy: 0.8641975308641975
# F_Value: 0.8070175438596491
# N: 1019

# %%
learning(4688, df, 0.001, 0.1)
# Out:
# svm.OneClassSVM(nu=0.001, kernel="rbf", gamma=0.1)
# Training Correct: 1970
# Training Error: 39
# True Negative: 1448
# False Positive: 26
# True Positive: 8
# False Negative: 8
# Recall: 0.5
# Precision: 0.23529411764705882
# Specificity: 0.9823609226594301
# Accuracy: 0.9771812080536912
# F_Value: 0.32
# N: 3499
